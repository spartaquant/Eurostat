# %%
import spartaquant as sq
sq = sq.spartaquant()
import eurostat

# %%
toc = eurostat.get_toc()

# %%
toc_df = eurostat.get_toc_df()
toc_df

# %%
# eurostat.get_data_df(code, flags=False)
eurostat.subset_toc_df(toc_df, 'unemployment')

# %%
unemployment_df = eurostat.get_data_df('une_rt_m', flags=False)
unemployment_df

# %%
unemployment_eu_df = unemployment_df[['s_adj', 'age', 'unit', 'sex', 'geo\\time', '2022M03']]
unemployment_eu_df = unemployment_eu_df[unemployment_eu_df['age'] == 'TOTAL']
unemployment_eu_df = unemployment_eu_df[unemployment_eu_df['s_adj'] == 'SA']
unemployment_eu_df = unemployment_eu_df[unemployment_eu_df['sex'] == 'T']
unemployment_eu_df = unemployment_eu_df[unemployment_eu_df['unit'] == 'PC_ACT']
unemployment_eu_df
# unemployment_df

# %%
unemployment_df.columns.tolist()
